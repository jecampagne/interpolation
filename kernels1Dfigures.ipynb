# %%
# %pylab inline
import numpy as np
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.gridspec as gridspec
params = {'legend.fontsize':14,
          'figure.figsize': (8, 8),
         'axes.labelsize': 16,
         'axes.titlesize': 16,
         'xtick.labelsize':16,
         'ytick.labelsize': 16}
pylab.rcParams.update(params)

# %%
import matplotlib.ticker as mtick
def decibel_formatter(unit='dB'):
    def format_value(value, pos=None):
        dB = 10*np.log10(value)
        return f'{dB:.0f} {unit}'
    return format_value

# %%
from  interp1DKernels  import *

# %% [markdown]
# # Reproduce & update Figure 1 and Table 1 of Gary M. Bernstein & Daniel Gruen 2014 article
# https://arxiv.org/pdf/1401.2636v2.pdf

# %%
figure(figsize=(6,4))

lab = ["Sinc","Lanczos Norm 3","Lanczos Norm 5","Cubic","Quintic (MZV)","Quintic (GB)","Quintic (JE)"]#, "BSplineC 3", "BSplineC 5"]
lsStyle = ["-"]*len(lab)
#lsStyle[-2]="-."
lsStyle[-1]="-."
kerU = [hatSincInterp,hatlanczos3,hatlanczos5,hat3,hat5MZV,hat5Gary,hat5JE]

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

uv = np.linspace(-0.3,0.3,1000)
for ik,kU in enumerate(kerU):
  plot(uv,kU(uv+1),label=lab[ik],ls=lsStyle[ik],c=colors[ik])
ylim([-0.005,0.005])
grid();
legend(loc='center right', bbox_to_anchor=(1.45, 0.5),fontsize=12);
# Fill in area under the curve and the horizontal lines
fill_between(x=uv, y1=0.001, y2=-0.001, color='gray',  interpolate=True, alpha=.1)
axvline(-0.25, linestyle='--', color='black')
axvline(0.25, linestyle='--', color='black');
axvline(-0.125, linestyle='--', color='black')
axvline(0.125, linestyle='--', color='black');
axvline(-0.5/6, linestyle='--', color='black')
axvline(0.5/6, linestyle='--', color='black');
ylabel(r"$\hat{K}(u+1)$")
xlabel(r"$u=x/N$");

plt.annotate(
    '', xy=(-0.5/6, -0.004), xycoords='data',
    xytext=(0.5/6, -0.004), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x6 padding', xy=(0, -0.004), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(-0.5/4, -0.003), xycoords='data',
    xytext=(0.5/4, -0.003), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x4 padding', xy=(0, -0.003), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(-0.5/2, -0.002), xycoords='data',
    xytext=(0.5/2, -0.002), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x2 padding', xy=(0, -0.002), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points');

# %%
figure(figsize=(6,4))

lab = ["Cubic","Quintic (MZV)", "Quintic (GB)","Quintic (JE)",]#,"BSplineC 3", "BSplineC 5"]#,"mks2021"]
lsStyle = ["-"]*len(lab)
#lsStyle[-2]="-."
lsStyle[-1]="-."
kerU = [hat3,hat5MZV,hat5Gary,hat5JE,]#,hatBsplineCard3,hatBsplineCard5]#,hatmks2021]

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']


uv = np.linspace(-0.2,0.2,1000)
for ik,kU in enumerate(kerU):
  plot(uv,kU(uv+1),label=lab[ik],ls=lsStyle[ik],c=colors[ik+3])
ylim([-0.003,0.003])
grid();
legend(loc='center right', bbox_to_anchor=(1.45, 0.5), fontsize=12);
# Fill in area under the curve and the horizontal lines
fill_between(x=uv, y1=0.0002, y2=-0.0002, color='blue',  interpolate=True, alpha=.1)
fill_between(x=uv, y1=0.001, y2=-0.001, color='gray',  interpolate=True, alpha=.1)
axvline(-0.125, linestyle='--', color='black')
axvline(0.125, linestyle='--', color='black');
#axvline(-0.25, linestyle='--', color='black')
#axvline(0.25, linestyle='--', color='black');
axvline(-0.5/6, linestyle='--', color='black')
axvline(0.5/6, linestyle='--', color='black');
ylabel(r"$\hat{K}(u+1)$")
xlabel(r"$u=x/N$");

plt.annotate(
    '', xy=(-0.5/6, -0.002), xycoords='data',
    xytext=(0.5/6, -0.002), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x6 padding', xy=(0, -0.002), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(-0.5/4, -0.0015), xycoords='data',
    xytext=(0.5/4, -0.0015), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x4 padding', xy=(0, -0.0015), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points');

#plt.annotate(
#    '', xy=(-0.5/2, -0.0010), xycoords='data',
#    xytext=(0.5/2, -0.0010), textcoords='data',
#    arrowprops={'arrowstyle': '<->'})
#plt.annotate(
#    'x2 padding', xy=(0, -0.0010), xycoords='data', ha='center',
#    xytext=(0, 1), textcoords='offset points')

# %%
figure(figsize=(6,4))

lab = ["Sinc","Lanczos Norm 3","Lanczos Norm 5","Cubic","Quintic (MZV)", "Quintic (GB)","Quintic (JE)"]#,"BSplineC 3","BSplineC 5"]#"mks2021"]
lsStyle = ["-"]*len(lab)
#lsStyle[-2]="-."
lsStyle[-1]="-."
kerU = [hatSincInterp,hatlanczos3,hatlanczos5,hat3,hat5MZV,hat5Gary,hat5JE]#,hatBsplineCard3, hatBsplineCard5]#hatmks2021]

#kerX = [sincInterp,lanczos3,lanczos5,h3,h5Gary,mks2021]
#lab = ["Sinc","Lanczos Norm 3","Lanczos Norm 5","Cubic","Quintic (GB)","mks2021"]
#lsStyle = ["-"]*len(lab)
#lsStyle[-1]="--"
#kerU = [hatSincInterp,hatlanczos3,hatlanczos5,hat3,hat5Gary,hatmks2021]

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

uv = np.linspace(-0.3,0.3,1000)
for ik,kU in enumerate(kerU):
  plot(uv,kU(uv+2),label=lab[ik],ls=lsStyle[ik],c=colors[ik])
ylim([-0.01,0.01])
grid();
legend(loc='center right', bbox_to_anchor=(1.45, 0.5), fontsize=12);
# Fill in area under the curve and the horizontal lines
fill_between(x=uv, y1=0.001, y2=-0.001, color='gray',  interpolate=True, alpha=.1)
axvline(-0.25, linestyle='--', color='black')
axvline(0.25, linestyle='--', color='black');
axvline(-0.125, linestyle='--', color='black')
axvline(0.125, linestyle='--', color='black');
axvline(-0.5/6, linestyle='--', color='black')
axvline(0.5/6, linestyle='--', color='black');
ylabel(r"$\hat{K}(u+2)$")
xlabel(r"$u=x/N$");

plt.annotate(
    '', xy=(-0.5/6, -0.0095), xycoords='data',
    xytext=(0.5/6, -0.0095), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x6 padding', xy=(0, -0.0095), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(-0.5/4, -0.008), xycoords='data',
    xytext=(0.5/4, -0.008), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x4 padding', xy=(0, -0.008), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(-0.5/2, -0.0065), xycoords='data',
    xytext=(0.5/2, -0.0065), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x2 padding', xy=(0, -0.0065), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points');

# %%
figure(figsize=(6,4))

lab = ["Sinc","Lanczos Norm 3","Lanczos Norm 5","Cubic","Quintic (MZV)", "Quintic (GB)","Quintic (JE)"]#,"BSplineC 3","BSplineC 5"]#"mks2021"]
lsStyle = ["-"]*len(lab)
#lsStyle[-2]="-."
lsStyle[-1]="-."
kerU = [hatSincInterp,hatlanczos3,hatlanczos5,hat3,hat5MZV,hat5Gary,hat5JE]#,hatBsplineCard3, hatBsplineCard5]#hatmks2021]

#kerX = [sincInterp,lanczos3,lanczos5,h3,h5Gary,mks2021]
#lab = ["Sinc","Lanczos Norm 3","Lanczos Norm 5","Cubic","Quintic (GB)","mks2021"]
#lsStyle = ["-"]*len(lab)
#lsStyle[-1]="--"
#kerU = [hatSincInterp,hatlanczos3,hatlanczos5,hat3,hat5Gary,hatmks2021]

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

uv = np.linspace(-0.3,0.3,1000)
for ik,kU in enumerate(kerU):
  plot(uv,kU(uv+3),label=lab[ik],ls=lsStyle[ik],c=colors[ik])
ylim([-0.01,0.01])
grid();
legend(loc='center right', bbox_to_anchor=(1.45, 0.5), fontsize=12);
# Fill in area under the curve and the horizontal lines
fill_between(x=uv, y1=0.001, y2=-0.001, color='gray',  interpolate=True, alpha=.1)
axvline(-0.25, linestyle='--', color='black')
axvline(0.25, linestyle='--', color='black');
axvline(-0.125, linestyle='--', color='black')
axvline(0.125, linestyle='--', color='black');
axvline(-0.5/6, linestyle='--', color='black')
axvline(0.5/6, linestyle='--', color='black');
ylabel(r"$\hat{K}(u+3)$")
xlabel(r"$u=x/N$");

plt.annotate(
    '', xy=(-0.5/6, -0.0095), xycoords='data',
    xytext=(0.5/6, -0.0095), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x6 padding', xy=(0, -0.0095), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(-0.5/4, -0.008), xycoords='data',
    xytext=(0.5/4, -0.008), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x4 padding', xy=(0, -0.008), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(-0.5/2, -0.0065), xycoords='data',
    xytext=(0.5/2, -0.0065), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x2 padding', xy=(0, -0.0065), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points');

# %%
def E0(u,ker,n=5):
  sum=0
  for j in range(1,n+1):
    sum += ker(j+u)+ker(j-u)
  return sum

# %%
figure(figsize=(6,4))

lab = ["Lanczos Norm 5", "Cubic","Quintic (MZV)","Quintic (GB)","Quintic (JE)"]#,"BSplineC 3","BSplineC 5"]#,"mks2021"]
lsStyle = ["-"]*len(lab)
#lsStyle[-2]="-."
lsStyle[-1]="-."
kerU = [hatlanczos5,hat3,hat5MZV,hat5Gary,hat5JE]#,hatBsplineCard3, hatBsplineCard5]#,hatmks2021]

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']


uv = np.linspace(0,0.2,1000)
for ik,kU in enumerate(kerU):
  plot(uv,E0(uv,kU),label=lab[ik],ls=lsStyle[ik],c=colors[ik+2])
ylim([-0.002,0.002])
grid();
legend(loc='center right', bbox_to_anchor=(1.45, 0.5), fontsize=12);
# Fill in area under the curve and the horizontal lines
fill_between(x=uv, y1=0.0002, y2=-0.0002, color='blue',  interpolate=True, alpha=.1)
fill_between(x=uv, y1=0.001, y2=-0.001, color='gray',  interpolate=True, alpha=.1)
#axvline(-0.125, linestyle='--', color='black')
axvline(0.125, linestyle='--', color='black');
#axvline(-0.25, linestyle='--', color='black')
#axvline(0.25, linestyle='--', color='black');
#axvline(-0.5/6, linestyle='--', color='black')
axvline(0.5/6, linestyle='--', color='black');
ylabel(r"$E_0(u)$")
xlabel(r"$u=x/N$");

plt.annotate(
    '', xy=(0, -0.0014), xycoords='data',
    xytext=(0.5/6, -0.0014), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x6 padding', xy=(0.5/12, -0.0014), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(0, -0.0012), xycoords='data',
    xytext=(0.5/4, -0.0012), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x4 padding', xy=(0.5/8, -0.0012), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points');

# %%
figure(figsize=(6,4))
#lab = ["Lanczos Norm 3","Lanczos Norm 5","Cubic","Quintic (GB)","Quintic (MZV)","Quintic (JE)","mks2021"]
lab = ["Lanczos Norm 3","Lanczos Norm 5","Cubic","Quintic (GB)","Quintic (MZV)","Quintic (JE)"]
lsStyle = ["-"]*len(lab)
#lsStyle[-2]="--"
lsStyle[-1]="-."
#kerU = [hatlanczos3,hatlanczos5,hat3,hat5Gary,hat5MZV,hat5JE,hatmks2021]

kerU = [hatlanczos3,hatlanczos5,hat3,hat5Gary,hat5MZV,hat5JE]



prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

uv = np.linspace(0,5,10_000)
for ik,kU in enumerate(kerU):
  plot(uv,np.abs(kU(uv)),label=lab[ik],ls=lsStyle[ik],c=colors[ik+2])
ylim([0,0.01])
xlabel(r"$u$");
ylabel(r"$\hat{K}(u)$")
grid();
legend(loc='center right', bbox_to_anchor=(1.45, 0.5), fontsize=12);
axhline(0.001, linestyle='--', color='black');

# %%
from scipy.optimize import fsolve

class RootFinder:
    def __init__(self, start, stop, step=0.01, root_dtype="float64", xtol=1e-9):

        self.start = start
        self.stop = stop
        self.step = step
        self.xtol = xtol
        self.roots = np.array([], dtype=root_dtype)

    def add_to_roots(self, x):

        if (x < self.start) or (x > self.stop):
            return  # outside range
        if any(abs(self.roots - x) < self.xtol):
            return  # root already found.

        self.roots = np.append(self.roots, x)

    def find(self, f, *args):
        current = self.start

        for x0 in np.arange(self.start, self.stop + self.step, self.step):
            if x0 < current:
                continue
            x = self.find_root(f, x0, *args)
            if x is None:  # no root found.
                continue
            current = x
            self.add_to_roots(x)

        return self.roots

    def find_root(self, f, x0, *args):

        x, _, ier, _ = fsolve(f, x0=x0, args=args, full_output=True, xtol=self.xtol)
        if ier == 1:
            return x[0]
        return None

# %%
lab = ["Lanczos Norm 3","Lanczos Norm 5","Cubic    ","Quintic (GB)","Quintic (MZV)","Quintic (JE)"]
kerU = [hatlanczos3,hatlanczos5,hat3,hat5Gary,hat5MZV,hat5JE]
for ik,kU in enumerate(kerU):
    r = RootFinder(1, 5, 0.01)
    def func(u):
        return np.abs(kU(u)) - 0.001
    uinit = 1.
    umax = r.find(func)
    print(lab[ik],'\t',np.around(np.max(umax),2))
# Out:
# Lanczos Norm 3 	 1.49
# Lanczos Norm 5 	 1.08
# Cubic     	 2.74
# Quintic (GB) 	 3.62
# Quintic (MZV) 	 1.7
# Quintic (JE) 	 3.69

# %%
lab = ["Lanczos Norm 3","Lanczos Norm 5","Cubic    ","Quintic (GB)","Quintic (MZV)","Quintic (JE)"]
kerU = [hatlanczos3,hatlanczos5,hat3,hat5Gary,hat5MZV,hat5JE]
for ik,kU in enumerate(kerU):
    print(">>>>>>> ",lab[ik],"<<<<<<<")
    for thres in [1/4,1/8,1/12]:
        uv = np.linspace(-thres,thres,50_000,endpoint=True)
        ghost=np.max(np.abs(kU(uv+1)))
        uv = np.linspace(0,thres,25_000,endpoint=True)
        e0=np.max(E0(uv,kU))
        print(np.around(thres,3),"\t",np.around(e0,5),"\t",np.around(ghost,5),"\t",np.around(np.max((e0,ghost)),5))
# Out:
# >>>>>>>  Lanczos Norm 3 <<<<<<<
# 0.25 	 0.00012 	 0.0128 	 0.0128
# 0.125 	 0.00012 	 0.00358 	 0.00358
# 0.083 	 0.00012 	 0.00353 	 0.00353
# >>>>>>>  Lanczos Norm 5 <<<<<<<
# 0.25 	 0.0036 	 0.00424 	 0.00424
# 0.125 	 2e-05 	 0.00225 	 0.00225
# 0.083 	 2e-05 	 0.00122 	 0.00122
# >>>>>>>  Cubic     <<<<<<<
# 0.25 	 0.0609 	 0.06256 	 0.06256
# 0.125 	 0.00449 	 0.00611 	 0.00611
# 0.083 	 0.00092 	 0.0016 	 0.0016
# >>>>>>>  Quintic (GB) <<<<<<<
# 0.25 	 0.02165 	 0.03696 	 0.03696
# 0.125 	 0.00045 	 0.00123 	 0.00123
# 0.083 	 4e-05 	 0.00016 	 0.00016
# >>>>>>>  Quintic (MZV) <<<<<<<
# 0.25 	 0.05446 	 0.05638 	 0.05638
# 0.125 	 0.00382 	 0.00483 	 0.00483
# 0.083 	 0.00077 	 0.0012 	 0.0012
# >>>>>>>  Quintic (JE) <<<<<<<
# 0.25 	 0.0299 	 0.01768 	 0.0299
# 0.125 	 0.00064 	 0.00031 	 0.00064
# 0.083 	 6e-05 	 3e-05 	 6e-05

# %% [markdown]
# # Towards $\times 2$ padding?

# %%
lanczos10 = partial(lanczos_norm,m=10)
hatlanczos10 = partial(hatlanczos_norm,m=10)

lanczos9 = partial(lanczos_norm,m=9)
hatlanczos9 = partial(hatlanczos_norm,m=9)

lanczos15 = partial(lanczos_norm,m=15)
hatlanczos15 = partial(hatlanczos_norm,m=15)

# %%
figure(figsize=(6,4))

lab = ["Sinc","Lanczos Norm 5","Lanczos Norm 9","Lanczos Norm 10","Quintic JE", "7th-ord JE"]#, "BSplineC 3", "BSplineC 5"]
lsStyle = ["-"]*len(lab)
#lsStyle[-2]="-."
lsStyle[-1]="-."
kerU = [hatSincInterp,hatlanczos5,hatlanczos9,hatlanczos10,hat5JE,hat7JE]

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

uv = np.linspace(-0.3,0.3,1000)
for ik,kU in enumerate(kerU):
  plot(uv,kU(uv+1),label=lab[ik],ls=lsStyle[ik],c=colors[ik])
ylim([-0.005,0.005])
grid();
legend(loc='center right', bbox_to_anchor=(1.45, 0.5),fontsize=12);
# Fill in area under the curve and the horizontal lines
fill_between(x=uv, y1=0.001, y2=-0.001, color='gray',  interpolate=True, alpha=.1)
axvline(-0.25, linestyle='--', color='black')
axvline(0.25, linestyle='--', color='black');
axvline(-0.125, linestyle='--', color='black')
axvline(0.125, linestyle='--', color='black');
axvline(-0.5/6, linestyle='--', color='black')
axvline(0.5/6, linestyle='--', color='black');
ylabel(r"$\hat{K}(u+1)$")
xlabel(r"$u=x/N$");

plt.annotate(
    '', xy=(-0.5/6, -0.004), xycoords='data',
    xytext=(0.5/6, -0.004), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x6 padding', xy=(0, -0.004), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(-0.5/4, -0.003), xycoords='data',
    xytext=(0.5/4, -0.003), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x4 padding', xy=(0, -0.003), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(-0.5/2, -0.002), xycoords='data',
    xytext=(0.5/2, -0.002), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x2 padding', xy=(0, -0.002), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points');

# %%
figure(figsize=(6,4))
lab = ["Lanczos Norm 5","Lanczos Norm 9","Lanczos Norm 10","Quintic JE", "7th-ord JE"]#, "BSplineC 3", "BSplineC 5"]
lsStyle = ["-"]*len(lab)
#lsStyle[-2]="-."
lsStyle[-1]="-."
kerU = [lanczos5,hatlanczos9,hatlanczos10,hat5JE,hat7JE]#,hatBsplineCard3, hatBsplineCard5]#,hatmks2021]

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']


uv = np.linspace(0,0.5,1000)
for ik,kU in enumerate(kerU):
  plot(uv,E0(uv,kU),label=lab[ik],ls=lsStyle[ik],c=colors[ik+1])
ylim([-0.002,0.002])
grid();
legend(loc='center right', bbox_to_anchor=(1.45, 0.5), fontsize=12);
# Fill in area under the curve and the horizontal lines
fill_between(x=uv, y1=0.0002, y2=-0.0002, color='blue',  interpolate=True, alpha=.1)
fill_between(x=uv, y1=0.001, y2=-0.001, color='gray',  interpolate=True, alpha=.1)
#axvline(-0.125, linestyle='--', color='black')
axvline(0.125, linestyle='--', color='black');
#axvline(-0.25, linestyle='--', color='black')
axvline(0.25, linestyle='--', color='black');
#axvline(-0.5/6, linestyle='--', color='black')
axvline(0.5/6, linestyle='--', color='black');
ylabel(r"$E_0(u)$")
xlabel(r"$u=x/N$");

plt.annotate(
    '', xy=(0, -0.0014), xycoords='data',
    xytext=(0.5/6, -0.0014), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x6 padding', xy=(0.5/12, -0.0014), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points')

plt.annotate(
    '', xy=(0, -0.0012), xycoords='data',
    xytext=(0.5/4, -0.0012), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x4 padding', xy=(0.5/8, -0.0012), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points');


plt.annotate(
    '', xy=(0, -0.0010), xycoords='data',
    xytext=(0.5/2, -0.0010), textcoords='data',
    arrowprops={'arrowstyle': '<->'})
plt.annotate(
    'x2 padding', xy=(0.5/8, -0.0010), xycoords='data', ha='center',
    xytext=(0, 1), textcoords='offset points');

# %%
figure(figsize=(10,4))
x = np.linspace(-11,11,10_000)
plot(x,np.abs(lanczos5(x)),label="Lanczos 5")
plot(x,np.abs(lanczos10(x)),label="Lanczos 10")
plot(x,np.abs(h5JE(x)),label="Quintic (JE)")
ax = plt.gca()
ax.set_xticks(np.arange(-11,12), minor=False)
#ax.set_yticks(np.arange(-0.2,0.2,0.1), minor=False)
ylim([1e-5,1.2])
grid();
legend();
yscale('log')
